# %% [markdown]
# <a href="https://colab.research.google.com/github/htrl-mockarin/Python-Project-1/blob/main/Python_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Download the dataset directly in Google Colab

# %%
# !wget -O nyc_schools.csv "https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv"
# Out:
# --2025-03-09 01:36:03--  https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24377626 (23M) [text/plain]
# Saving to: ‘nyc_schools.csv’
#
# nyc_schools.csv     100%[===================>]  23.25M   146MB/s    in 0.2s
#
# 2025-03-09 01:36:03 (146 MB/s) - ‘nyc_schools.csv’ saved [24377626/24377626]

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'nyc_schools.csv', 'sample_data']

# %% [markdown]
# import pandas library

# %%
import pandas as pd

# %% [markdown]
# load dataset

# %%
df = pd.read_csv ("nyc_schools.csv")

# %% [markdown]
# get dataset information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   School DBN                   212331 non-null  object
#  1   School Name                  212331 non-null  object
#  2   School Level                 212331 non-null  object
#  3   Regents Exam                 212321 non-null  object
#  4   Year                         212331 non-null  int64
#  5   Total Tested                 212331 non-null  int64
#  6   Mean Score                   212331 non-null  object
#  7   Number Scoring Below 65      212331 non-null  object
#  8   Percent Scoring Below 65     212331 non-null  object
#  9   Number Scoring 65 or Above   212331 non-null  object
#  10  Percent Scoring 65 or Above  212331 non-null  object
#  11  Number Scoring 80 or Above   212331 non-null  object
# ...

# %% [markdown]
# Summary stastics

# %%
df.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %% [markdown]
# Display all column names in the dataset

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['School DBN',
#  'School Name',
#  'School Level',
#  'Regents Exam',
#  'Year',
#  'Total Tested',
#  'Mean Score',
#  'Number Scoring Below 65',
#  'Percent Scoring Below 65',
#  'Number Scoring 65 or Above',
#  'Percent Scoring 65 or Above',
#  'Number Scoring 80 or Above',
#  'Percent Scoring 80 or Above',
#  'Number Scoring CR',
#  'Percent Scoring CR']

# %% [markdown]
# Handle missing values

# %%
# Check for Missing Values
missing_values = df.isnull().sum()

#Handle Missing Values (Replacing missing numeric values with the median)
df.fillna(df.median(numeric_only=True), inplace=True)

#Verify that missing values have been handled
missing_values_after = df.isnull().sum()

# Display the missing values before and after handling using Pandas display
missing_df = pd.DataFrame({
    "Missing Before": missing_values,
    "Missing After": missing_values_after})
from IPython.display import display

print("Missing Values Handled:")
display(missing_df)
# Out:
# Missing Values Handled:
#                              Missing Before  Missing After
# School DBN                                0              0
# School Name                               0              0
# School Level                              0              0
# Regents Exam                             10             10
# Year                                      0              0
# Total Tested                              0              0
# Mean Score                                0              0
# Number Scoring Below 65                   0              0
# Percent Scoring Below 65                  0              0
# Number Scoring 65 or Above                0              0
# Percent Scoring 65 or Above               0              0
# Number Scoring 80 or Above                0              0
# Percent Scoring 80 or Above               0              0
# Number Scoring CR                         0              0
# ...

# %%
df['School Name'].unique()
# Out:
# array(['P.S. 034 Franklin D. Roosevelt', 'P.S. 140 Nathan Straus',
#        'P.S. 184m Shuang Wen', ..., 'Family Life Academy Charter School',
#        'Harriet Tubman Charter School', 'Icahn Charter School'],
#       dtype=object)

# %% [markdown]
# Choose a school

# %%
school_name = "Family Life Academy Charter School"
df_school = df[df['School Name'] == school_name]

df_school.head()
# Out:
#       School DBN                         School Name School Level  \
# 19462     84X705  Family Life Academy Charter School          K-8
# 19463     84X705  Family Life Academy Charter School          K-8
# 19464     84X705  Family Life Academy Charter School          K-8
# 54214     84X705  Family Life Academy Charter School          K-8
# 54215     84X705  Family Life Academy Charter School          K-8
#
#              Regents Exam  Year  Total Tested Mean Score  \
# 19462  Living Environment  2015            21       75.8
# 19463  Living Environment  2016            23       76.5
# 19464  Living Environment  2017            24       73.3
# 54214  Living Environment  2015            20          s
# 54215  Living Environment  2015             1          s
#
#       Number Scoring Below 65 Percent Scoring Below 65  \
# 19462                       0                        0
# 19463                       2                      8.7
# ...

# %% [markdown]
# Choose a performance metric

# %%
df.columns.tolist()
# Out:
# ['School DBN',
#  'School Name',
#  'School Level',
#  'Regents Exam',
#  'Year',
#  'Total Tested',
#  'Mean Score',
#  'Number Scoring Below 65',
#  'Percent Scoring Below 65',
#  'Number Scoring 65 or Above',
#  'Percent Scoring 65 or Above',
#  'Number Scoring 80 or Above',
#  'Percent Scoring 80 or Above',
#  'Number Scoring CR',
#  'Percent Scoring CR']

# %% [markdown]
# Choose and describe  "Mean Score"

# %%
score_column = "Mean Score"
df_school[score_column].describe()
# Out:
# count     26
# unique    15
# top        s
# freq       8
# Name: Mean Score, dtype: object

# %% [markdown]
# Compare it to all schools

# %%
df[score_column].describe()
# Out:
# count     212331
# unique       748
# top            s
# freq       75222
# Name: Mean Score, dtype: object

# %%
df['Regents Exam'].unique()
# Out:
# array(['Common Core Algebra', 'Living Environment', 'Common Core English',
#        'Algebra2/Trigonometry', 'Common Core Algebra2',
#        'Common Core Geometry', 'English', 'Geometry',
#        'Global History and Geography', 'Integrated Algebra',
#        'Physical Settings/Chemistry', 'Physical Settings/Earth Science',
#        'U.S. History and Government', 'Physical Settings/Physics', nan],
#       dtype=object)

# %% [markdown]
# Compare it to all schools

# %%
school_name = "Family Life Academy Charter School"
df_school = df[df['School Name']== school_name]

df["Mean Score"].describe()
# Out:
# count     212331
# unique       748
# top            s
# freq       75222
# Name: Mean Score, dtype: object

# %% [markdown]
# Select numeric columns for calculations

# %%
numeric_columns = ["Total Tested", "Mean Score", "Percent Scoring 65 or Above", "Percent Scoring 80 or Above"]
numeric_columns = [col for col in numeric_columns if col in df_school.columns]

# %% [markdown]
# Calculate Mean, Median, and Standard Deviation for the chosen school

# %%
if not df_school.empty:
    school_stats = {
        "Mean": df_school[numeric_columns].mean(numeric_only=True),
        "Median": df_school[numeric_columns].median(numeric_only=True),
        "Standard Deviation": df_school[numeric_columns].std(numeric_only=True)
    }
    school_stats_df = pd.DataFrame(school_stats)
else:
    school_stats_df = None
    print(f"Error: '{school_name}' not found in the dataset.")

# %% [markdown]
# Compare Mean Score by Regents Exam

# %%
if 'Regents Exam' in df.columns:  # Ensure the column exists
    regents_stats = df.groupby("Regents Exam")["Mean Score"].describe()
else:
    regents_stats = None
    print("Error: 'Regents Exam' information is not available in the dataset.")

# %% [markdown]
# Calculate statistics for the entire dataset

# %%
dataset_stats = {
    "Mean": df[numeric_columns].mean(numeric_only=True),
    "Median": df[numeric_columns].median(numeric_only=True),
    "Standard Deviation": df[numeric_columns].std(numeric_only=True)
}
dataset_stats_df = pd.DataFrame(dataset_stats)

# %% [markdown]
# Display all calculated statistics

# %%
from IPython.display import display

if school_stats_df is not None:
    print("\n Statistics for Family Life Academy Charter School:")
    display(school_stats_df)

if regents_stats is not None:
    print("\n Mean Score by Regents Exam:")
    display(regents_stats)

print("\n Statistics for Entire Dataset:")
display(dataset_stats_df)
# Out:
#  Statistics for Family Life Academy Charter School:
#                    Mean  Median  Standard Deviation
# Total Tested  13.076923    12.0            6.834753
#  Mean Score by Regents Exam:
#                                  count unique top  freq
# Regents Exam
# Algebra2/Trigonometry            10788    655   s  5356
# Common Core Algebra              29254    519   s  9705
# Common Core Algebra2              7915    469   s  3557
# Common Core English              19878    669   s  6559
# Common Core Geometry             15267    566   s  5721
# English                          11091    537   s  4307
# Geometry                          8509    528   s  4162
# Global History and Geography     19192    602   s  4479
# Integrated Algebra               11022    428   s  4714
# Living Environment               25539    528   s  7296
# Physical Settings/Chemistry      11670    510   s  5310
# Physical Settings/Earth Science  15971    624   s  5574
# ...

# %% [markdown]
# Create a bar chart comparing School Performance with the Overall Mean Score

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=regents_mean_scores.index,
            y=regents_mean_scores.values,
            color="pink",
            label="Borough/District Average")

plt.axhline(school_mean_score,
            color="red",
            linestyle="dashed",
            label=f"{school_name} Mean Score")

plt.axhline(overall_mean_score,
            color="green",
            linestyle="dashed",
            label="Overall NYC Mean Score")

plt.xticks(rotation=90)
plt.title(f"Comparison of {school_name} Mean Score with Regents Exam and Overall NYC")
plt.xlabel("Regents Exam")
plt.ylabel("Mean Score")
plt.legend()
plt.show()

# %% [markdown]
# In conclusion, Family Life Academy Charter School is performing consistently well, meeting or exceeding not only the borough but also NYC averages in most subjects. While some variation exists between subjects, the school demonstrates strong overall academic performance in Regents exams.
